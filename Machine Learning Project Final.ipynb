# %%
#Importing Required Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import Dataset
df=pd.read_csv('C:\\Users\Avi Bansal\Desktop\AIML\Project-Apparent Temprature Prediction\weather_data.csv')

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      5999.000000               5999.000000  5999.000000
# mean         10.217695                  8.958658     0.779488
# std          10.565425                 11.923712     0.173051
# min         -14.088889                -22.094444     0.270000
# 25%           1.094444                 -1.538889     0.680000
# 50%          10.050000                 10.050000     0.830000
# 75%          18.722222                 18.722222     0.920000
# max          34.005556                 36.400000     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count        5999.000000             5999.000000      5999.000000      5999.0
# mean           10.007362              190.349558         9.476875         0.0
# std             6.536619              107.026792         4.038583         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %% [markdown]
# # <h2>Clean the Dataset

# %%
#To check if data contains null values or not so that we can clean the dataset
df.isnull()
# Out:
#       Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0              False    False        False            False
# 1              False    False        False            False
# 2              False    False        False            False
# 3              False    False        False            False
# 4              False    False        False            False
# 5              False    False        False            False
# 6              False    False        False            False
# 7              False    False        False            False
# 8              False    False        False            False
# 9              False    False        False            False
# 10             False    False        False            False
# 11             False    False        False            False
# 12             False    False        False            False
# 13             False    False        False            False
# 14             False    False        False            False
# ...

# %%
#Taking the count of null values
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# <h8>Since there are no null values so we can continue to our next step</h8>

# %%
df.keys()
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df['Summary'].describe()
# Out:
# count              5999
# unique               14
# top       Partly Cloudy
# freq               1791
# Name: Summary, dtype: object

# %%
df['Precip Type'].describe()
# Out:
# count     5999
# unique       2
# top       rain
# freq      4762
# Name: Precip Type, dtype: object

# %%
df['Loud Cover'].describe()
# Out:
# count    5999.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: Loud Cover, dtype: float64

# %% [markdown]
#  <h5><li>Since Loud Cover column has only 1 value through out so it can be dropped.</li></h5>
#  <h5><li>We can also drop  formatted date column as it has no use in predicting weather.</li></h5>
#  <h2>Now Perform EDA</h2>

# %%
df.Summary.value_counts()
# Out:
# Partly Cloudy               1791
# Mostly Cloudy               1473
# Overcast                    1230
# Clear                        853
# Foggy                        576
# Breezy and Overcast           25
# Breezy and Mostly Cloudy      20
# Breezy and Partly Cloudy       7
# Breezy and Foggy               7
# Humid and Mostly Cloudy        6
# Windy and Overcast             4
# Humid and Partly Cloudy        3
# Windy and Partly Cloudy        2
# Windy and Foggy                2
# Name: Summary, dtype: int64

# %%
df1=df[['Summary', 'Precip Type', 'Temperature (C)','Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
       'Wind Bearing (degrees)', 'Visibility (km)','Pressure (millibars)', 'Daily Summary']]

# %%
df1.apply(np.max)
# Out:
# Summary                        Windy and Partly Cloudy
# Precip Type                                       snow
# Temperature (C)                                34.0056
# Apparent Temperature (C)                          36.4
# Humidity                                             1
# Wind Speed (km/h)                              45.9333
# Wind Bearing (degrees)                             359
# Visibility (km)                                   16.1
# Pressure (millibars)                           1045.14
# Daily Summary               Partly cloudy until night.
# dtype: object

# %%
sns.boxplot(data=df['Visibility (km)'])

# %%
sns.boxplot(data=df['Humidity'])

# %%
sns.countplot(x='Precip Type',data=df1)

# %%
df1[['Wind Speed (km/h)','Wind Bearing (degrees)','Temperature (C)','Pressure (millibars)']].hist(figsize=(12,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024449432A58>,
# ...
#       dtype=object)

# %% [markdown]
# # Corelation matrix

# %%
cor_mat=df1[df1.columns].corr()
sns.heatmap(cor_mat)

# %%
cor_mat=df1[df1.columns].corr()
sns.heatmap(cor_mat,annot=True, cmap = 'magma')

# %% [markdown]
# <h5>Since Apparent temprature has very low correlation with<br><br>
#     <li>Wind speed</li><br>
#     <li>Visibility</li><br>
#     <li>Wind Bearing</li><br>
#     So we can remove these columns for linear regression.</h5>
# <h5>We have to also remove Categorical Variables<br><br>
#     <li>Summary</li><br>
#     <li>Precip Type</li><br>
#     <li>Daily Summary</li><br>
#     from this dataset to perform linear regression</h5>

# %% [markdown]
# # Building Linear regression Model

# %%
df2=df1[['Temperature (C)','Apparent Temperature (C)', 'Humidity','Visibility (km)']]

# %%
df2.head()
# Out:
#    Temperature (C)  Apparent Temperature (C)  Humidity  Visibility (km)
# 0         9.472222                  7.388889      0.89          15.8263
# 1         9.355556                  7.227778      0.86          15.8263
# 2         9.377778                  9.377778      0.89          14.9569
# 3         8.288889                  5.944444      0.83          15.8263
# 4         8.755556                  6.977778      0.83          15.8263

# %%
X=df2[['Temperature (C)','Humidity','Visibility (km)']]
y=df2['Apparent Temperature (C)']

# %%
from sklearn.feature_selection import VarianceThreshold
z=VarianceThreshold(0.5).fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, \
                                                    random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# # Making Predictions

# %%
y_pred = regressor.predict(X_test)

# %%
dfp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
dfp
# Out:
#          Actual  Predicted
# 4320  21.461111  21.463214
# 2006  -0.361111   1.226651
# 5688   5.066667   6.809571
# 472   21.255556  21.330259
# 1370  15.405556  15.306612
# 1457  25.950000  26.213137
# 5267   3.938889   1.623848
# 3484   1.716667  -0.343294
# 1145  22.861111  23.029996
# 130   12.200000  10.924895
# 1136  17.294444  17.006779
# 4658  18.883333  19.145124
# 1161  17.750000  17.723549
# 2152  11.322222  10.204448
# 559   10.933333   9.497046
# 916   16.644444  16.450409
# 4278  17.072222  17.140438
# 4394   8.066667   6.885443
# 4008  21.116667  21.801772
# 4910  14.800000  14.060438
# 2569  -3.288889  -1.009707
# 4166  21.294444  21.573289
# 4336  30.377778  31.852971
# 528    8.627778   8.024035
# 5915  21.205556  20.796047
# 4404  11.172222  10.388049
# 5913  15.394444  14.683890
# 247   12.266667  11.444497
# 4583  21.500000  21.907228
# 1675   0.188889  -1.928177
# ...         ...        ...
# 4141  32.938889  33.812078
# 2104   6.333333   6.917487
# ...

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  1.0125596476075347
# Mean Squared Error:  1.8247390975355309
# Root Mean Squared Error:  1.3508290408247563

# %%
print(metrics.r2_score(y_test, y_pred))
# Out:
# 0.9872289041144179
